# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = np.zeros((600,600,3), np.uint8)
cv2.line(img,(0,0),(600,600),(255,0,0),5)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FDBE77B0E50>

# %%
img = np.zeros((600,600,3), np.uint8)
cv2.line(img,(0,0),(600,600),(255,0,0),5)
cv2.line(img,(600,0),(0,600),(20,255,0),10)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FDBE773F490>

# %%
img = np.zeros((600,600,3), np.uint8)
cv2.line(img,(0,0),(600,600),(255,0,0),5)
cv2.line(img,(600,0),(0,600),(20,255,0),10)
cv2.circle(img,(300,300),10,(0,0,255),5)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FDBE7752110>

# %%
img = np.zeros((600,600,3), np.uint8)
cv2.line(img,(0,0),(600,600),(255,0,0),5)
cv2.line(img,(600,0),(0,600),(20,255,0),10)
cv2.circle(img,(300,300),10,(0,0,255),5)
cv2.rectangle(img,(0,0),(100,150),(0,0,255),5)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FDBE7752D10>

# %%
img = np.zeros((600,600,3), np.uint8)
cv2.line(img,(0,0),(600,600),(255,0,0),5)
cv2.line(img,(600,0),(0,600),(20,255,0),10)
cv2.circle(img,(300,300),50,(0,0,255),2)
cv2.rectangle(img,(0,0),(100,150),(0,0,255),5)
cv2.rectangle(img,(350,350),(250,250),(255,255,0),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FDBE7758A50>

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'Saul',(225,400), font, 2,(255,255,255),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FDBE7752490>
